# %% [markdown]
# ## Test Data Preprocessing
# In this notebook, I preprocess the test data. The procedure is the same for both the train and test subsets:
#
# - Get correct amount (10% of entire dataset for each class for test)
# - Generate one hot encoded labels and store in Numpy ndarray (test labels)
# Generate Mel Spectrograms for each input audio file
# - Store Mel Spectrograms in Numpy ndarray (test samples)
# - Pickle test samples and test labels.

# %%
import numpy as np
from glob import glob
import librosa 
import matplotlib.pyplot as plt
import pandas as pd
import pylab
import librosa.display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# get paths to files 
speech_directory = '/content/drive/MyDrive/Mignot Lab Research/Experiments/one_sample/one-second-splits/speech'
no_speech_directory ='/content/drive/MyDrive/Mignot Lab Research/Experiments/one_sample/one-second-splits/no_speech'

# %%
# create a list of all of the files in the folder using glob 
speech_subset = glob(speech_directory + '/*.wav')
no_speech_subset = glob(no_speech_directory + '/*.wav')

# %%
print(len(speech_subset))
print(len(no_speech_subset))
# Out:
# 2487
# 30219

# %%
# testing subset 
test_num = len(speech_subset) - round(.90*len(speech_subset))
print(test_num)
# Out:
# 249

# %%
len(speech_subset) - test_num
# Out:
# 2238

# %%
2238 + 249
# Out:
# 2487

# %%
speech_test = speech_subset[2238:]
no_speech_test = no_speech_subset[2238:2487]
print(len(speech_test))
print(len(no_speech_test))
# Out:
# 249
# 249

# %%
temp_speech_labels_test = []
for i in range(len(speech_test)):
    temp_speech_labels_test.append(1) # 1 = speech


temp_no_speech_labels_test = []
for i in range(len(no_speech_test)):
    temp_no_speech_labels_test.append(0) # 0 = speech

print(len(temp_speech_labels_test))
print(len(temp_no_speech_labels_test))
# Out:
# 249
# 249

# %%
test_labels = temp_speech_labels_test + temp_no_speech_labels_test
test_labels = np.array(test_labels)

# %%
test_data_points_raw = speech_test + no_speech_test

# %%
print(len(test_labels))
print(len(test_data_points_raw))
# Out:
# 498
# 498

# %% [markdown]
# Check: correct amounts.

# %%
type(test_labels)
# Out:
# numpy.ndarray

# %%
import pickle
out_file = open("/content/drive/MyDrive/Mignot Lab Research/Experiments/one_sample/one-second-splits/test_labels_real.pkl", "wb")
pickle.dump(test_labels, out_file)
out_file.close()

# %%
test = []

# %%
for elem in test_data_points_raw:
    y, sr = librosa.load(elem)
    time = np.arange(0, len(y)) / sr
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,
                                    fmax=8000)
    test.append(S)

# %%
test = np.array(test)

# %%
out_file = open("/content/drive/MyDrive/Mignot Lab Research/Experiments/one_sample/one-second-splits/test_samples.pkl", "wb")
pickle.dump(test, out_file)
out_file.close()
